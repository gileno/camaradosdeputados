# %%
arquivo = open("alice.txt", "r", encoding='utf-8')

# %%
contador = {}
conteudo = arquivo.read()

# %%
texto = "Python é legal" 
print(texto.replace("Python", "Java"))
print(texto)
# Out:
# Java é legal
# Python é legal

# %%
conteudo = conteudo.replace("\n", " ").replace("\r", " ").lower().strip()

# %%
palavras = conteudo.split(" ")

# %%
len(palavras)
# Out:
# 28379

# %%
for palavra in palavras:
    if palavra in contador:
        contador[palavra] = contador[palavra] + 1
    else:
        contador[palavra] = 1

# %%
print(contador)
# Out:
# {'alice’s': 11, 'adventures': 4, 'in': 351, 'wonderland': 2, '': 1930, 'lewis': 1, 'carroll': 1, 'the': 1605, 'millennium': 1, 'fulcrum': 1, 'edition': 1, '3.0': 1, 'chapter': 12, 'i.': 1, 'down': 78, 'rabbit-hole': 3, 'alice': 221, 'was': 333, 'beginning': 11, 'to': 706, 'get': 43, 'very': 139, 'tired': 7, 'of': 493, 'sitting': 10, 'by': 56, 'her': 208, 'sister': 5, 'on': 142, 'bank,': 2, 'and': 766, 'having': 10, 'nothing': 22, 'do:': 1, 'once': 19, 'or': 68, 'twice': 1, 'she': 518, 'had': 176, 'peeped': 3, 'into': 67, 'book': 3, 'reading,': 1, 'but': 116, 'it': 362, 'no': 67, 'pictures': 4, 'conversations': 1, 'it,': 38, '‘and': 55, 'what': 91, 'is': 71, 'use': 16, 'a': 614, 'book,’': 2, 'thought': 63, '‘without': 1, 'conversations?’': 1, 'so': 126, 'considering': 3, 'own': 9, 'mind': 5, '(as': 3, 'well': 27, 'as': 249, 'could,': 7, 'for': 135, 'hot': 4, 'day': 11, 'made': 29, 'feel': 8, 'sleepy': 3, 'stupid),': 1, 'whether': 11, 'pleasure': 2, 'making': 8, 'daisy-chain': 1, 'woul
# ...

# %%
teste = {"a": 1, "b": 2, "c": 3}
print(teste)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
max(contador.values())
# Out:
# 1930

# %%
palavra_mais_usada = None
quantidade = 0
for palavra in contador:
    if contador[palavra] > quantidade:
        quantidade = contador[palavra]
        palavra_mais_usada = palavra

# %%
palavra_mais_usada
# Out:
# ''

# %%
contador = {}
for palavra in palavras:
    if palavra:
        if palavra in contador:
            contador[palavra] = contador[palavra] + 1
        else:
            contador[palavra] = 1

# %%
palavra_mais_usada = None
quantidade = 0
for palavra in contador:
    if contador[palavra] > quantidade:
        quantidade = contador[palavra]
        palavra_mais_usada = palavra
print(palavra_mais_usada)
print(quantidade)
# Out:
# the
# 1605

# %%
sorted(contador.keys(), key=lambda k: contador[k])[-1]
# Out:
# 'the'
