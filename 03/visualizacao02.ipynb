# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1, 10, 101)

# %%
plt.plot(x, np.sin(x), 'b--')
plt.show()

# %%
import seaborn as sns

# %%
plt.plot(x, np.sin(x), 'b--')
plt.show()

# %%
sns.set_style('white')

# %%
plt.plot(x, np.sin(x), 'b--')
plt.show()

# %%
sns.set_style('ticks')
plt.plot(x, np.sin(x), 'b--')
plt.show()
