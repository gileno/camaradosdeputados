# %%
import pandas as pd
import pydataset

# %%
titanic = pydataset.data('titanic')

# %%
titanic.columns
# Out:
# Index(['class', 'age', 'sex', 'survived'], dtype='object')

# %%
titanic['class'].describe()
# Out:
# count          1316
# unique            3
# top       3rd class
# freq            706
# Name: class, dtype: object

# %%
titanic['class'].nbytes
# Out:
# 10528

# %%
# %%time
titanic[titanic['class'] == '3rd class']
# Out:
# Wall time: 3 ms
#           class     age    sex survived
# 611   3rd class  adults    man      yes
# 612   3rd class  adults    man      yes
# 613   3rd class  adults    man      yes
# 614   3rd class  adults    man      yes
# 615   3rd class  adults    man      yes
# 616   3rd class  adults    man      yes
# 617   3rd class  adults    man      yes
# 618   3rd class  adults    man      yes
# 619   3rd class  adults    man      yes
# 620   3rd class  adults    man      yes
# 621   3rd class  adults    man      yes
# 622   3rd class  adults    man      yes
# 623   3rd class  adults    man      yes
# 624   3rd class  adults    man      yes
# 625   3rd class  adults    man      yes
# 626   3rd class  adults    man      yes
# 627   3rd class  adults    man      yes
# 628   3rd class  adults    man      yes
# 629   3rd class  adults    man      yes
# 630   3rd class  adults    man      yes
# 631   3rd class  adults    man      yes
# 632   3rd class  adults    man      yes
# ...

# %%
titanic['class'] = titanic['class'].astype('category')

# %%
titanic['class'].nbytes
# Out:
# 1340

# %%
titanic.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes
