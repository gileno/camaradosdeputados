# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('primary_results.csv')

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
len(df)
# Out:
# 24611

# %%
df.groupby('candidate').aggregate({'votes': [np.min, np.mean, np.max]})
# Out:
#                 votes
#                  amin         mean    amax
# candidate
#  No Preference      0    23.225071     580
#  Uncommitted        0     0.434343      16
# Ben Carson          0   338.258238    9945
# Bernie Sanders      0  2844.019501  434656
# Carly Fiorina       0   139.366972    3612
# Chris Christie      1   223.422018    7144
# Donald Trump        0  3709.576408  179130
# Hillary Clinton     0  3731.855410  590502
# Jeb Bush            2   609.103226    9575
# John Kasich         0  1160.052705  101217
# Marco Rubio         0  1299.834051  111898
# Martin O'Malley     0     7.595960     152
# Mike Huckabee       2    33.787879     565
# Rand Paul           2    85.646465    1633
# Rick Santorum       0    18.000000     234
# Ted Cruz            0  2120.191299  147721

# %%
df[df['votes'] == 590502]
# Out:
#            state state_abbreviation       county    fips     party  \
# 1386  California                 CA  Los Angeles  6037.0  Democrat
#
#             candidate   votes  fraction_votes
# 1386  Hillary Clinton  590502            0.57

# %%
df[(df['fraction_votes'] == 1) & (df['candidate'] == 'Hillary Clinton')]
# Out:
#           state state_abbreviation        county        fips     party  \
# 8142      Maine                 ME         Amity  92300012.0  Democrat
# 8160      Maine                 ME      Atkinson  92300020.0  Democrat
# 8168      Maine                 ME          Avon  92300024.0  Democrat
# 8186      Maine                 ME   Beaver Cove  92300033.0  Democrat
# 8188      Maine                 ME    Beddington  92300034.0  Democrat
# 8292      Maine                 ME       Caswell  92300088.0  Democrat
# 8334      Maine                 ME      Crawford  92300111.0  Democrat
# 8400      Maine                 ME      Edinburg  92300144.0  Democrat
# 8576      Maine                 ME     Lakeville  92300235.0  Democrat
# 8650      Maine                 ME      Masardis  92300274.0  Democrat
# 8700      Maine                 ME        Moscow  92300301.0  Democrat
# 8710      Maine                 ME    New Canada  92300308.0  Democrat
# ...

# %%
def fraction_votes_filter(row):
    return row['votes'].sum() > 2000000
df.groupby('state').filter(fraction_votes_filter)
# Out:
#             state state_abbreviation        county     fips       party  \
# 1349   California                 CA       Alameda   6001.0    Democrat
# 1350   California                 CA       Alameda   6001.0    Democrat
# 1351   California                 CA        Alpine   6003.0    Democrat
# 1352   California                 CA        Alpine   6003.0    Democrat
# 1353   California                 CA        Amador   6005.0    Democrat
# 1354   California                 CA        Amador   6005.0    Democrat
# 1355   California                 CA         Butte   6007.0    Democrat
# 1356   California                 CA         Butte   6007.0    Democrat
# 1357   California                 CA     Calaveras   6009.0    Democrat
# 1358   California                 CA     Calaveras   6009.0    Democrat
# 1359   California                 CA        Colusa   6011.0    Democrat
# 1360   California                 CA        Colusa   6011.0    Democrat
# ...

# %%
len(df.groupby('state').filter(fraction_votes_filter))
# Out:
# 6832
