# %%
import pandas as pd

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
copacabana = pd.read_csv('copacabana.csv', delimiter=';')

# %%
copacabana.head()
# Out:
#    Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 0        1      3.0   0.01         1144        311         146      969501
# 1        0      2.0   0.01         2456        502         254     1472861
# 2        0      2.0   0.01         2448        772         229     1803724
# 3        0      2.0   0.01         1615        428         310     1124331
# 4        0      2.0   1.00         2358        586         287     1165764
#
#    RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  AreaConstruida  \
# 0     1028834         999168    1750  509   37.0          1              95
# 1     1137759        1305310    2300  484   30.0          1              71
# 2     1512475        1658100    2350  920   44.0          1              58
# 3     1370600        1247466    2200  930   43.0          1              88
# 4     1177933        1171849    2150  918   42.0          1              68
#
#    VAL_UNIT            X            Y
# ...

# %%
copacabana['Quartos'].describe()
# Out:
# count    1675.000000
# mean        1.767510
# std         1.142523
# min         0.010000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: Quartos, dtype: float64

# %%
len(copacabana)
# Out:
# 1675

# %%
copacabana[copacabana['Quartos'] == 6]
# Out:
#      Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 748        1      6.0    2.0         2500         35         743     1524600
#
#      RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  AreaConstruida  \
# 748     1275377        1399989    4100  360   58.0          1             668
#
#      VAL_UNIT          X           Y
# 748      4491  686456.25  7458801.05

# %%
quartos6 = copacabana[copacabana['Quartos'] == 6].iloc[0]

# %%
quartos6
# Out:
# Posicao                 1.00
# Quartos                 6.00
# Vagas                   2.00
# DistIpanema          2500.00
# DistPraia              35.00
# DistFavela            743.00
# RendaMedia        1524600.00
# RendaMovel        1275377.00
# RendaMovelRua     1399989.00
# Vu2009               4100.00
# Mes                   360.00
# Idade                  58.00
# Tipologia               1.00
# AreaConstruida        668.00
# VAL_UNIT             4491.00
# X                  686456.25
# Y                 7458801.05
# Name: 748, dtype: float64

# %%
quartos6['VAL_UNIT'] * quartos6['AreaConstruida']
# Out:
# 2999988.0

# %%
copacabana[copacabana['Quartos'] == 5]
# Out:
#       Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 173         1      5.0   0.01         2696        154         712     1083455
# 1521        1      5.0   3.00         3044         31         609     1524600
#
#       RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  \
# 173       649733         866594    2000  425   55.0          1
# 1521     1168222        1346411    4100  405   34.0          1
#
#       AreaConstruida  VAL_UNIT            X           Y
# 173               38      6316  686522.9800  7458989.87
# 1521             430      5000  686965.3201  7459109.71

# %%
copacabana['TOTAL'] = copacabana['VAL_UNIT'] * copacabana['AreaConstruida']

# %%
copacabana['TOTAL']
# Out:
# 0        416005
# 1        460009
# 2        720012
# 3        990000
# 4        909976
# 5        790024
# 6        670015
# 7        249990
# 8        319990
# 9        299997
# 10       390000
# 11       299992
# 12       410000
# 13       749990
# 14       625022
# 15       619972
# 16       309986
# 17       340032
# 18       760000
# 19       870020
# 20       250005
# 21       340005
# 22       210000
# 23       139995
# 24       270000
# 25        90000
# 26       350010
# 27       450022
# 28       329975
# 29       210033
#          ...
# 1645     792984
# 1646    1393956
# 1647     810027
# 1648    1800022
# 1649     886990
# 1650     969992
# 1651     499968
# 1652     560032
# 1653     284984
# 1654    2199998
# 1655    2179944
# 1656     300011
# 1657     180000
# 1658     280016
# 1659     229992
# 1660     342012
# 1661     699996
# 1662     710024
# 1663    1320000
# 1664     300024
# 1665     700024
# 1666     390000
# 1667     434980
# 1668     219996
# ...

# %%
populacao_pe = pd.read_excel('total_populacao_pernambuco.xls')

# %%
populacao_pe.head()
# Out:
#   Código do município      Nome do município  Total da população 2000  \
# 0             2600054           Abreu e Lima                  89039.0
# 1             2600104  Afogados da Ingazeira                  32922.0
# 2             2600203                Afrânio                  15014.0
# 3             2600302              Agrestina                  20036.0
# 4             2600401             Água Preta                  28531.0
#
#    Total de homens  Total de mulheres  Total da população urbana  \
# 0          45165.0            49263.0                    86589.0
# 1          16790.0            18301.0                    27406.0
# 2           8751.0             8837.0                     5859.0
# 3          10938.0            11742.0                    16955.0
# 4          16581.0            16465.0                    18708.0
#
#    Total da população rural  Total da população 2010
# 0                    7839.0                  94428.0
# ...

# %%
populacao_pe['Total da população 2010']
# Out:
# 0        94428.0
# 1        35091.0
# 2        17588.0
# 3        22680.0
# 4        33046.0
# 5        40007.0
# 6        13761.0
# 7        37414.0
# 8        22363.0
# 9        21925.0
# 10       10204.0
# 11       18144.0
# 12       77363.0
# 13       69157.0
# 14       12765.0
# 15       40720.0
# 16       11349.0
# 17       20236.0
# 18       72412.0
# 19       12005.0
# 20       58675.0
# 21       35178.0
# 22       45506.0
# 23       37828.0
# 24       37570.0
# 25        8851.0
# 26        7307.0
# 27       45192.0
# 28       12537.0
# 29       51990.0
#          ...
# 157      17000.0
# 158      79241.0
# 159      18331.0
# 160      33723.0
# 161      40306.0
# 162       5744.0
# 163      58444.0
# 164      26430.0
# 165      12704.0
# 166      22073.0
# 167      20745.0
# 168      24923.0
# 169       6737.0
# 170       9256.0
# 171      53823.0
# 172      35631.0
# 173      13055.0
# 174      26116.0
# 175      15006.0
# 176      24254.0
# 177       7925.0
# ...

# %%
populacao_pe.columns
# Out:
# Index(['Código do município', 'Nome do município', 'Total da população 2000',
#        'Total de homens', 'Total de mulheres', 'Total da população urbana',
#        'Total da população rural', 'Total da população 2010'],
#       dtype='object')

# %%
populacao_pe.columns = ['Codigo', 'Nome', 'Total2000',
       'TotalHomens', 'TotalMulheres', 'TotalUrbana',
       'TotalRural', 'Total2010']

# %%
populacao_pe.head()
# Out:
#     Codigo                   Nome  Total2000  TotalHomens  TotalMulheres  \
# 0  2600054           Abreu e Lima    89039.0      45165.0        49263.0
# 1  2600104  Afogados da Ingazeira    32922.0      16790.0        18301.0
# 2  2600203                Afrânio    15014.0       8751.0         8837.0
# 3  2600302              Agrestina    20036.0      10938.0        11742.0
# 4  2600401             Água Preta    28531.0      16581.0        16465.0
#
#    TotalUrbana  TotalRural  Total2010
# 0      86589.0      7839.0    94428.0
# 1      27406.0      7685.0    35091.0
# 2       5859.0     11729.0    17588.0
# 3      16955.0      5725.0    22680.0
# 4      18708.0     14338.0    33046.0

# %%
populacao_pe.sort_values('Total2010')
# Out:
#                                      Codigo                      Nome  \
# 60                                  2605459       Fernando de Noronha
# 81                                  2607406                 Itacuruba
# 78                                  2607109                 Ingazeira
# 35                                  2603405                   Calumbi
# 162                                 2614402                   Solidão
# 131                                 2611533                   Quixaba
# 169                                 2615102                 Terezinha
# 69                                  2606309                   Granito
# 26                                  2602506                  Brejinho
# 73                                  2606705                 Ibirajuba
# 180                                 2616183         Vertente do Lério
# 177                                 2615904                Tuparetama
# ...

# %%
numeros = pd.Series([1,2,3,4])

# %%
numeros * pd.Series([2,3,4,5])
# Out:
# 0     2
# 1     6
# 2    12
# 3    20
# dtype: int64

# %%
resultado = numeros * pd.Series([2,3,4,5])

# %%
resultado.apply(lambda i: '%02d' % i)
# Out:
# 0    02
# 1    06
# 2    12
# 3    20
# dtype: object

# %%
resultado.apply(lambda i: '%.2f' % i)
# Out:
# 0     2.00
# 1     6.00
# 2    12.00
# 3    20.00
# dtype: object

# %%
formatar = lambda i: '%.2f' % i

# %%
formatar
# Out:
# <function __main__.<lambda>>

# %%
formatar(10)
# Out:
# '10.00'
